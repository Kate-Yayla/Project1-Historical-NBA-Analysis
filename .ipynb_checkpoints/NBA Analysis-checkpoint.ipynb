# %%
# import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

# %%
# import the dataset
team_Data = pd.read_csv("Resources/teamData.csv")
player_Data = pd.read_csv("Resources/playerData.csv")
cross_ref = pd.read_csv("Resources/crossReference.csv")

# %%
cross_ref.head()
# Out:
#          Team   TM
# 0       76ers  PHI
# 1  Blackhawks  TRI
# 2     Bobcats  CHA
# 3     Bommers  STB
# 4      Braves  BLB

# %%
combined_team_data = pd.merge(team_Data, cross_ref, on="Team")
combined_team_data
# Out:
#       Year     Team Record  Winning Percentage   TM
# 0     1964    76ers  34-46               0.425  PHI
# 1     1965    76ers  40-40               0.500  PHI
# 2     1966    76ers  55-25               0.688  PHI
# 3     1967    76ers  68-13               0.840  PHI
# 4     1968    76ers  62-20               0.756  PHI
# ...    ...      ...    ...                 ...  ...
# 2278  2013  Wizards  29-53               0.354  WAS
# 2279  2014  Wizards  44-38               0.537  WAS
# 2280  2015  Wizards  46-36               0.561  WAS
# 2281  2016  Wizards  41-41               0.500  WAS
# 2282  2017  Wizards  23-20               0.535  WAS
#
# [2283 rows x 5 columns]

# %%
combined_team_data = combined_team_data.loc[(combined_team_data["Year"] >= 1986) & (combined_team_data["Year"]< 2018)]
combined_team_data
# Out:
#       Year     Team Record  Winning Percentage   TM
# 22    1986    76ers  54-28               0.659  PHI
# 23    1987    76ers  45-37               0.549  PHI
# 24    1988    76ers  36-46               0.439  PHI
# 25    1989    76ers  46-36               0.561  PHI
# 26    1990    76ers  53-29               0.646  PHI
# ...    ...      ...    ...                 ...  ...
# 2278  2013  Wizards  29-53               0.354  WAS
# 2279  2014  Wizards  44-38               0.537  WAS
# 2280  2015  Wizards  46-36               0.561  WAS
# 2281  2016  Wizards  41-41               0.500  WAS
# 2282  2017  Wizards  23-20               0.535  WAS
#
# [1441 rows x 5 columns]

# %%
player_Data.head()
# Out:
#    Index    Year         Player  Pos   Age   Tm     G  GS  MP  PER  ...  \
# 0     10  1950.0  Charlie Black  F-C  28.0  AND  29.0 NaN NaN  NaN  ...
# 1     19  1950.0  Frankie Brian    G  26.0  AND  64.0 NaN NaN  NaN  ...
# 2     31  1950.0    Jake Carter  F-C  25.0  AND  11.0 NaN NaN  NaN  ...
# 3     37  1950.0     Bill Closs   SF  28.0  AND  64.0 NaN NaN  NaN  ...
# 4     73  1950.0    Frank Gates    G  29.0  AND  64.0 NaN NaN  NaN  ...
#
#      FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF     PTS
# 0  0.688  NaN  NaN  NaN   88.0  NaN  NaN  NaN  133.0   279.0
# 1  0.824  NaN  NaN  NaN  189.0  NaN  NaN  NaN  192.0  1138.0
# 2  0.667  NaN  NaN  NaN    8.0  NaN  NaN  NaN   32.0    38.0
# 3  0.718  NaN  NaN  NaN  160.0  NaN  NaN  NaN  190.0   752.0
# 4  0.622  NaN  NaN  NaN   91.0  NaN  NaN  NaN  147.0   287.0
#
# [5 rows x 53 columns]

# %%
# Taking player Dataframe from 1986 till 2017
player_Data = player_Data.loc[(player_Data["Year"] >= 1986.0) & (player_Data["Year"]< 2018.0)]
player_Data["Year"] = player_Data["Year"].astype(int)
player_Data
# Out:
#        Index  Year            Player Pos   Age   Tm     G    GS      MP   PER  \
# 263     7937  1986       John Battle  SG  23.0  ATL  64.0   0.0   639.0  11.7
# 264     7963  1986      Antoine Carr  PF  24.0  ATL  17.0   0.0   258.0  14.4
# 265     7973  1986   Lorenzo Charles  SF  22.0  ATL  36.0   0.0   273.0  11.5
# 266     8000  1986      Johnny Davis  SG  30.0  ATL  27.0   7.0   402.0  13.9
# 267     8050  1986    Scott Hastings  PF  25.0  ATL  62.0   0.0   650.0   7.5
# ...      ...   ...               ...  ..   ...  ...   ...   ...     ...   ...
# 24592  13341  1997    Rod Strickland  PG  30.0  WSB  82.0  81.0  2997.0  19.7
# 24593  13365  1997       Ben Wallace  PF  22.0  WSB  34.0   0.0   197.0   6.0
# 24594  13374  1997      Chris Webber  PF  23.0  WSB  72.0  72.0  2806.0  21.8
# 24595  13382  1997     Chris Whitney  PG  25.0  WSB  82.0   1.0  1117.0  15.2
# 24596  13394  1997  Lorenzo Williams   C  27.0  WSB  19.0   0.0   264.0   8.0
#
#        ...    FT%    ORB    DRB    TRB    AST    STL    BLK    TOV     PF  \
# 263    ...  0.728   12.0   50.0   62.0   74.0   23.0    3.0   47.0   80.0
# 264    ...  0.667   16.0   36.0   52.0   14.0    7.0   15.0   14.0   51.0
# 265    ...  0.667   13.0   26.0   39.0    8.0    2.0    6.0   18.0   37.0
# 266    ...  0.864    2.0   17.0   19.0  112.0   13.0    0.0   38.0   32.0
# 267    ...  0.857   44.0   80.0  124.0   26.0   14.0    8.0   40.0  118.0
# ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 24592  ...  0.738   95.0  240.0  335.0  727.0  143.0   14.0  270.0  166.0
# 24593  ...  0.300   25.0   33.0   58.0    2.0    8.0   11.0   18.0   27.0
# 24594  ...  0.565  238.0  505.0  743.0  331.0  122.0  137.0  230.0  258.0
# 24595  ...  0.832   13.0   91.0  104.0  182.0   49.0    4.0   68.0  100.0
# 24596  ...  0.714   28.0   41.0   69.0    4.0    6.0    8.0   18.0   49.0
#
#           PTS
# 263     277.0
# 264     116.0
# 265     122.0
# 266     144.0
# 267     193.0
# ...       ...
# 24592  1410.0
# 24593    38.0
# 24594  1445.0
# 24595   430.0
# 24596    45.0
#
# [16738 rows x 53 columns]

# %%
complete_nba_data = pd.merge(player_Data, combined_team_data, left_on=["Tm","Year"], right_on=["TM","Year"])
complete_nba_data
# Out:
#        Index  Year            Player Pos   Age   Tm     G    GS      MP   PER  \
# 0       7937  1986       John Battle  SG  23.0  ATL  64.0   0.0   639.0  11.7
# 1       7963  1986      Antoine Carr  PF  24.0  ATL  17.0   0.0   258.0  14.4
# 2       7973  1986   Lorenzo Charles  SF  22.0  ATL  36.0   0.0   273.0  11.5
# 3       8000  1986      Johnny Davis  SG  30.0  ATL  27.0   7.0   402.0  13.9
# 4       8050  1986    Scott Hastings  PF  25.0  ATL  62.0   0.0   650.0   7.5
# ...      ...   ...               ...  ..   ...  ...   ...   ...     ...   ...
# 15257  13341  1997    Rod Strickland  PG  30.0  WSB  82.0  81.0  2997.0  19.7
# 15258  13365  1997       Ben Wallace  PF  22.0  WSB  34.0   0.0   197.0   6.0
# 15259  13374  1997      Chris Webber  PF  23.0  WSB  72.0  72.0  2806.0  21.8
# 15260  13382  1997     Chris Whitney  PG  25.0  WSB  82.0   1.0  1117.0  15.2
# 15261  13394  1997  Lorenzo Williams   C  27.0  WSB  19.0   0.0   264.0   8.0
#
#        ...    AST    STL    BLK    TOV     PF     PTS     Team  Record  \
# 0      ...   74.0   23.0    3.0   47.0   80.0   277.0    Hawks   50-32
# 1      ...   14.0    7.0   15.0   14.0   51.0   116.0    Hawks   50-32
# 2      ...    8.0    2.0    6.0   18.0   37.0   122.0    Hawks   50-32
# 3      ...  112.0   13.0    0.0   38.0   32.0   144.0    Hawks   50-32
# 4      ...   26.0   14.0    8.0   40.0  118.0   193.0    Hawks   50-32
# ...    ...    ...    ...    ...    ...    ...     ...      ...     ...
# 15257  ...  727.0  143.0   14.0  270.0  166.0  1410.0  Bullets   44-38
# 15258  ...    2.0    8.0   11.0   18.0   27.0    38.0  Bullets   44-38
# 15259  ...  331.0  122.0  137.0  230.0  258.0  1445.0  Bullets   44-38
# 15260  ...  182.0   49.0    4.0   68.0  100.0   430.0  Bullets   44-38
# 15261  ...    4.0    6.0    8.0   18.0   49.0    45.0  Bullets   44-38
#
#        Winning Percentage   TM
# 0                   0.610  ATL
# 1                   0.610  ATL
# 2                   0.610  ATL
# 3                   0.610  ATL
# 4                   0.610  ATL
# ...                   ...  ...
# 15257               0.537  WSB
# 15258               0.537  WSB
# 15259               0.537  WSB
# 15260               0.537  WSB
# 15261               0.537  WSB
#
# [15262 rows x 57 columns]

# %% [markdown]
# #### Question 1 Markdown

# %%
four_factor = complete_nba_data[["Year","Player","TM","eFG%","TOV%","ORB%","FT%","Winning Percentage"]]
four_factor
# Out:
#        Year            Player   TM   eFG%  TOV%  ORB%    FT%  \
# 0      1986       John Battle  ATL  0.455  15.0   2.1  0.728
# 1      1986      Antoine Carr  ATL  0.527  11.8   6.9  0.667
# 2      1986   Lorenzo Charles  ATL  0.557  14.8   5.3  0.667
# 3      1986      Johnny Davis  ATL  0.435  22.2   0.6  0.864
# 4      1986    Scott Hastings  ATL  0.418  17.4   7.5  0.857
# ...     ...               ...  ...    ...   ...   ...    ...
# 15257  1997    Rod Strickland  WSB  0.472  16.9   3.8  0.738
# 15258  1997       Ben Wallace  WSB  0.348  24.7  15.1  0.300
# 15259  1997      Chris Webber  WSB  0.543  15.0  10.1  0.565
# 15260  1997     Chris Whitney  WSB  0.509  15.2   1.4  0.832
# 15261  1997  Lorenzo Williams  WSB  0.645  34.6  12.6  0.714
#
#        Winning Percentage
# 0                   0.610
# 1                   0.610
# 2                   0.610
# 3                   0.610
# 4                   0.610
# ...                   ...
# 15257               0.537
# 15258               0.537
# 15259               0.537
# 15260               0.537
# 15261               0.537
#
# [15262 rows x 8 columns]

# %%
four_factor = complete_nba_data[["Year","Player","TM","eFG%","TOV%","ORB%","FT%","Winning Percentage"]]
four_factor["eFG%"] = four_factor["eFG%"]*100
four_factor
# Out:
# C:\Users\Jay D\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        Year            Player   TM  eFG%  TOV%  ORB%    FT%  \
# 0      1986       John Battle  ATL  45.5  15.0   2.1  0.728
# 1      1986      Antoine Carr  ATL  52.7  11.8   6.9  0.667
# 2      1986   Lorenzo Charles  ATL  55.7  14.8   5.3  0.667
# 3      1986      Johnny Davis  ATL  43.5  22.2   0.6  0.864
# 4      1986    Scott Hastings  ATL  41.8  17.4   7.5  0.857
# ...     ...               ...  ...   ...   ...   ...    ...
# 15257  1997    Rod Strickland  WSB  47.2  16.9   3.8  0.738
# 15258  1997       Ben Wallace  WSB  34.8  24.7  15.1  0.300
# 15259  1997      Chris Webber  WSB  54.3  15.0  10.1  0.565
# 15260  1997     Chris Whitney  WSB  50.9  15.2   1.4  0.832
# 15261  1997  Lorenzo Williams  WSB  64.5  34.6  12.6  0.714
#
#        Winning Percentage
# 0                   0.610
# 1                   0.610
# 2                   0.610
# 3                   0.610
# 4                   0.610
# ...                   ...
# 15257               0.537
# 15258               0.537
# 15259               0.537
# 15260               0.537
# 15261               0.537
#
# [15262 rows x 8 columns]

# %%
four_factor["Four Factor Ratings"] = round(((0.4*four_factor["eFG%"]) 
                                      - (0.25*four_factor["TOV%"]) 
                                      + (0.2*four_factor["ORB%"]) 
                                      + (0.15*four_factor["FT%"])),3)

four_factor
# Out:
# C:\Users\Jay D\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#        Year            Player   TM  eFG%  TOV%  ORB%    FT%  \
# 0      1986       John Battle  ATL  45.5  15.0   2.1  0.728
# 1      1986      Antoine Carr  ATL  52.7  11.8   6.9  0.667
# 2      1986   Lorenzo Charles  ATL  55.7  14.8   5.3  0.667
# 3      1986      Johnny Davis  ATL  43.5  22.2   0.6  0.864
# 4      1986    Scott Hastings  ATL  41.8  17.4   7.5  0.857
# ...     ...               ...  ...   ...   ...   ...    ...
# 15257  1997    Rod Strickland  WSB  47.2  16.9   3.8  0.738
# 15258  1997       Ben Wallace  WSB  34.8  24.7  15.1  0.300
# 15259  1997      Chris Webber  WSB  54.3  15.0  10.1  0.565
# 15260  1997     Chris Whitney  WSB  50.9  15.2   1.4  0.832
# 15261  1997  Lorenzo Williams  WSB  64.5  34.6  12.6  0.714
#
#        Winning Percentage  Four Factor Ratings
# 0                   0.610               14.979
# 1                   0.610               19.610
# 2                   0.610               19.740
# 3                   0.610               12.100
# 4                   0.610               13.999
# ...                   ...                  ...
# 15257               0.537               15.526
# 15258               0.537               10.810
# 15259               0.537               20.075
# 15260               0.537               16.965
# 15261               0.537               19.777
#
# [15262 rows x 9 columns]

# %%
four_factor_30seasons = four_factor.loc[(four_factor["Year"] >= 1986) & (four_factor["Year"]< 2018)]
four_factor_30seasons
# Out:
#        Year            Player   TM  eFG%  TOV%  ORB%    FT%  \
# 0      1986       John Battle  ATL  45.5  15.0   2.1  0.728
# 1      1986      Antoine Carr  ATL  52.7  11.8   6.9  0.667
# 2      1986   Lorenzo Charles  ATL  55.7  14.8   5.3  0.667
# 3      1986      Johnny Davis  ATL  43.5  22.2   0.6  0.864
# 4      1986    Scott Hastings  ATL  41.8  17.4   7.5  0.857
# ...     ...               ...  ...   ...   ...   ...    ...
# 15257  1997    Rod Strickland  WSB  47.2  16.9   3.8  0.738
# 15258  1997       Ben Wallace  WSB  34.8  24.7  15.1  0.300
# 15259  1997      Chris Webber  WSB  54.3  15.0  10.1  0.565
# 15260  1997     Chris Whitney  WSB  50.9  15.2   1.4  0.832
# 15261  1997  Lorenzo Williams  WSB  64.5  34.6  12.6  0.714
#
#        Winning Percentage  Four Factor Ratings
# 0                   0.610               14.979
# 1                   0.610               19.610
# 2                   0.610               19.740
# 3                   0.610               12.100
# 4                   0.610               13.999
# ...                   ...                  ...
# 15257               0.537               15.526
# 15258               0.537               10.810
# 15259               0.537               20.075
# 15260               0.537               16.965
# 15261               0.537               19.777
#
# [15262 rows x 9 columns]

# %%
team_data_30seasons = four_factor_30seasons.groupby(["TM","Year"]).mean()
team_data_30seasons = team_data_30seasons.round(3)
team_data_30seasons
# Out:
#             eFG%    TOV%   ORB%    FT%  Winning Percentage  \
# TM  Year
# ATL 1986  47.450  17.325  5.606  0.753               0.610
#     1987  43.747  16.253  7.140  0.751               0.695
#     1988  50.220  14.667  6.160  0.739               0.610
#     1989  45.615  16.038  6.431  0.745               0.634
#     1990  45.372  12.317  5.444  0.752               0.500
# ...          ...     ...    ...    ...                 ...
# WSB 1993  50.468  13.900  9.116  0.708               0.268
#     1994  44.900  15.184  6.140  0.751               0.293
#     1995  47.431  15.200  5.962  0.727               0.256
#     1996  49.605  13.390  7.890  0.731               0.476
#     1997  46.240  18.387  7.253  0.691               0.537
#
#           Four Factor Ratings
# TM  Year
# ATL 1986               15.883
#     1987               16.632
#     1988               17.764
#     1989               16.512
#     1990               17.222
# ...                       ...
# WSB 1993               17.449
#     1994               16.845
#     1995               16.474
#     1996               17.757
#     1997               16.754
#
# [905 rows x 6 columns]

# %%
# eFG% vs Winning % correlation

x_axis_efg = team_data_30seasons["eFG%"]
y_axis_efg = team_data_30seasons["Winning Percentage"]

(slope_efg, intercept_efg, r_value_efg, p_value_efg, std_err_efg) = stats.linregress(x_axis_efg,y_axis_efg)

regress_value_efg = slope_efg*x_axis_efg + intercept_efg

line_eq_efg = "y = " + str(round(slope_efg,2)) + "x + " + str(round(intercept_efg,2))


if r_value_efg > 0:
    print(f"Correlation Coefficient Value is {round(r_value_efg,3)}\n"
         f"There is a positive correlation between Effective Field Goal and Winning percentages")
elif r_value_efg < 0:
    print(f"Correlation Coefficient Value is {round(r_value_efg,3)}\n"
         f"There is a negative correlation between Effective Field Goal and Winning percentages")
else:
    print(f"Correlation Coefficient Value is {round(r_value_efg,3)}\n"
         f"There is a no concrete correlation between Effective Field Goal and Winning percentages")
# Out:
# Correlation Coefficient Value is 0.296
# There is a positive correlation between Effective Field Goal and Winning percentages

# %%
# plot eFG% against winning%

plt.scatter(x_axis_efg, y_axis_efg, marker='.')

plt.plot(x_axis_efg,regress_value_efg, "r-")

plt.annotate(line_eq_efg,(36.5,0.8), fontsize=14, color="red")
plt.xlabel("Effective Field Goal % (eFG%)", fontsize=12)
plt.ylabel("Winning Percentage", fontsize=12)
plt.title("Impact of Effective Field Goal on Winning", fontsize=16)
plt.tight_layout()

# Will uncomment save fig code after final code is ready
#plt.savefig("Visualizations/Impact of Effective Field Goal on Winning.jpg")

plt.show()

# %%
# TOV% vs Winning % correlation

x_axis_tov = team_data_30seasons["TOV%"]
y_axis_tov = team_data_30seasons["Winning Percentage"]

(slope_tov, intercept_tov, r_value_tov, p_value_tov, std_err_tov) = stats.linregress(x_axis_tov,y_axis_tov)

regress_value_tov = slope_tov*x_axis_tov + intercept_tov

line_eq_tov = "y = " + str(round(slope_tov,2)) + "x + " + str(round(intercept_tov,2))


if r_value_tov > 0:
    print(f"Correlation Coefficient Value is {round(r_value_tov,3)}\n"
         f"There is a positive correlation between Turnover Rate and Winning percentages")
elif r_value_tov < 0:
    print(f"Correlation Coefficient Value is {round(r_value_tov,3)}\n"
         f"There is a negative correlation between Turnover Rate and Winning percentages")
else:
    print(f"Correlation Coefficient Value is {round(r_value_tov,3)}\n"
         f"There is a no concrete correlation between Turnover Rate and Winning percentages")
# Out:
# Correlation Coefficient Value is -0.092
# There is a negative correlation between Turnover Rate and Winning percentages

# %%
# plot TOV% against winning%

plt.scatter(x_axis_tov, y_axis_tov, marker='.')

plt.plot(x_axis_tov,regress_value_tov, "r-")

plt.annotate(line_eq_tov,(17,0.85), fontsize=14, color="red")
plt.xlabel("Turnover Rate % (TOV%)", fontsize=12)
plt.ylabel("Winning Percentage", fontsize=12)
plt.title("Impact of Turnover Rate on Winning", fontsize=16)
plt.tight_layout()

# Will uncomment save fig code after final code is ready
#plt.savefig("Visualizations/Impact of Turnover Rate on Winning.jpg")

plt.show()

# %%
# ORB% vs Winning % correlation

x_axis_orb = team_data_30seasons["ORB%"]
y_axis_orb = team_data_30seasons["Winning Percentage"]

(slope_orb, intercept_orb, r_value_orb, p_value_orb, std_err_orb) = stats.linregress(x_axis_orb,y_axis_orb)

regress_value_orb = slope_orb*x_axis_orb + intercept_orb

line_eq_orb = "y = " + str(round(slope_orb,2)) + "x + " + str(round(intercept_orb,2))


if r_value_orb > 0:
    print(f"Correlation Coefficient Value is {round(r_value_orb,3)}\n"
         f"There is a positive correlation between Offensive Rebound Rate and Winning percentages")
elif r_value_orb < 0:
    print(f"Correlation Coefficient Value is {round(r_value_orb,3)}\n"
         f"There is a negative correlation between Offensive Rebound Rate and Winning percentages")
else:
    print(f"Correlation Coefficient Value is {round(r_value_orb,3)}\n"
         f"There is a no concrete correlation between Offensive Rebound Rate and Winning percentages")
# Out:
# Correlation Coefficient Value is 0.063
# There is a positive correlation between Offensive Rebound Rate and Winning percentages

# %%
# plot ORB% against winning%

plt.scatter(x_axis_orb, y_axis_orb, marker='.')

plt.plot(x_axis_orb,regress_value_orb, "r-")

plt.annotate(line_eq_orb,(8.5,0.8), fontsize=14, color="red")
plt.xlabel("Offensive Rebound Rate % (ORB%)", fontsize=12)
plt.ylabel("Winning Percentage", fontsize=12)
plt.title("Impact of Offensive Rebound Rate on Winning", fontsize=16)
plt.xlim(2.5,13.5)
plt.tight_layout()


# Will uncomment save fig code after final code is ready
#plt.savefig("Visualizations/Impact of Offensive Rebound Rate on Winning.jpg")

plt.show()

# %%
# FT% vs Winning % correlation

x_axis_ft = team_data_30seasons["FT%"]
y_axis_ft = team_data_30seasons["Winning Percentage"]

(slope_ft, intercept_ft, r_value_ft, p_value_ft, std_err_ft) = stats.linregress(x_axis_ft,y_axis_ft)

regress_value_ft = slope_ft*x_axis_ft + intercept_ft

line_eq_ft = "y = " + str(round(slope_ft,2)) + "x + " + str(round(intercept_ft,2))


if r_value_ft > 0:
    print(f"Correlation Coefficient Value is {round(r_value_ft,3)}\n"
         f"There is a positive correlation between Free Throw and Winning percentages")
elif r_value_ft < 0:
    print(f"Correlation Coefficient Value is {round(r_value_ft,3)}\n"
         f"There is a negative correlation between Free Throw and Winning percentages")
else:
    print(f"Correlation Coefficient Value is {round(r_value_ft,3)}\n"
         f"There is a no concrete correlation between Free Throw and Winning percentages")
# Out:
# Correlation Coefficient Value is 0.074
# There is a positive correlation between Free Throw and Winning percentages

# %%
# plot FT% against winning%

plt.scatter(x_axis_ft, y_axis_ft, marker='.')

plt.plot(x_axis_ft,regress_value_ft, "r-")

plt.annotate(line_eq_ft,(0.78,0.15), fontsize=14, color="red")
plt.xlabel("Free Throw Rate % (FT%)", fontsize=12)
plt.ylabel("Winning Percentage", fontsize=12)
plt.title("Impact of Free Throw Rate on Winning", fontsize=16)
plt.xlim(0.6,0.88)
plt.tight_layout()

# Will uncomment save fig code after final code is ready
#plt.savefig("Visualizations/Impact of Free Throw Rate on Winning.jpg")

plt.show()

# %% [markdown]
# #### Markdown Analysis

# %%
# Four Factor Rating vs Winning % correlation

x_axis_4ff = team_data_30seasons["Four Factor Ratings"]
y_axis_4ff = team_data_30seasons["Winning Percentage"]

(slope_4ff, intercept_4ff, r_value_4ff, p_value_4ff, std_err_4ff) = stats.linregress(x_axis_4ff,y_axis_4ff)

regress_value_4ff = slope_4ff*x_axis_4ff + intercept_4ff

line_eq_4ff = "y = " + str(round(slope_4ff,2)) + "x + " + str(round(intercept_4ff,2))


if r_value_4ff > 0:
    print(f"Correlation Coefficient Value is {round(r_value_4ff,3)}\n"
         f"There is a positive correlation between Four Factor Ratings and Winning percentages")
elif r_value_4ff < 0:
    print(f"Correlation Coefficient Value is {round(r_value_4ff,3)}\n"
         f"There is a negative correlation between Four Factor Ratings and Winning percentages")
else:
    print(f"Correlation Coefficient Value is {round(r_value_4ff,3)}\n"
         f"There is a no concrete correlation between Four Factor Ratings and Winning percentages")
# Out:
# Correlation Coefficient Value is 0.377
# There is a positive correlation between Four Factor Ratings and Winning percentages

# %%
# plot Four Factor Ratings against winning%

plt.scatter(x_axis_4ff, y_axis_4ff, marker='.')

plt.plot(x_axis_4ff,regress_value_4ff, "r-")

plt.annotate(line_eq_4ff,(12.5,0.8), fontsize=14, color="red")
plt.xlabel("Four Factor Ratings", fontsize=12)
plt.ylabel("Winning Percentage", fontsize=12)
plt.title("Impact of Four Factor Ratings on Winning", fontsize=16)
plt.xlim(12,20.5)
plt.tight_layout()

# Will uncomment save fig code after final code is ready
#plt.savefig("Visualizations/Impact of Four Factor Ratings on Winning.jpg")

plt.show()

# %% [markdown]
# #### 2017 Season Analysis

# %%
team_data_30seasons["Predicted Winning Percentage"] = round(((slope_4ff * team_data_30seasons["Four Factor Ratings"]) + 
                                                             intercept_4ff),3)
team_data_30seasons
# Out:
#             eFG%    TOV%   ORB%    FT%  Winning Percentage  \
# TM  Year
# ATL 1986  47.450  17.325  5.606  0.753               0.610
#     1987  43.747  16.253  7.140  0.751               0.695
#     1988  50.220  14.667  6.160  0.739               0.610
#     1989  45.615  16.038  6.431  0.745               0.634
#     1990  45.372  12.317  5.444  0.752               0.500
# ...          ...     ...    ...    ...                 ...
# WSB 1993  50.468  13.900  9.116  0.708               0.268
#     1994  44.900  15.184  6.140  0.751               0.293
#     1995  47.431  15.200  5.962  0.727               0.256
#     1996  49.605  13.390  7.890  0.731               0.476
#     1997  46.240  18.387  7.253  0.691               0.537
#
#           Four Factor Ratings  Predicted Winning Percentage
# TM  Year
# ATL 1986               15.883                         0.467
#     1987               16.632                         0.507
#     1988               17.764                         0.567
#     1989               16.512                         0.500
#     1990               17.222                         0.538
# ...                       ...                           ...
# WSB 1993               17.449                         0.550
#     1994               16.845                         0.518
#     1995               16.474                         0.498
#     1996               17.757                         0.566
#     1997               16.754                         0.513
#
# [905 rows x 7 columns]

# %%
team_data_30seasons["Residuals"] = (team_data_30seasons["Winning Percentage"] - 
                                    team_data_30seasons["Predicted Winning Percentage"])
team_data_30seasons
# Out:
#             eFG%    TOV%   ORB%    FT%  Winning Percentage  \
# TM  Year
# ATL 1986  47.450  17.325  5.606  0.753               0.610
#     1987  43.747  16.253  7.140  0.751               0.695
#     1988  50.220  14.667  6.160  0.739               0.610
#     1989  45.615  16.038  6.431  0.745               0.634
#     1990  45.372  12.317  5.444  0.752               0.500
# ...          ...     ...    ...    ...                 ...
# WSB 1993  50.468  13.900  9.116  0.708               0.268
#     1994  44.900  15.184  6.140  0.751               0.293
#     1995  47.431  15.200  5.962  0.727               0.256
#     1996  49.605  13.390  7.890  0.731               0.476
#     1997  46.240  18.387  7.253  0.691               0.537
#
#           Four Factor Ratings  Predicted Winning Percentage  Residuals
# TM  Year
# ATL 1986               15.883                         0.467      0.143
#     1987               16.632                         0.507      0.188
#     1988               17.764                         0.567      0.043
#     1989               16.512                         0.500      0.134
#     1990               17.222                         0.538     -0.038
# ...                       ...                           ...        ...
# WSB 1993               17.449                         0.550     -0.282
#     1994               16.845                         0.518     -0.225
#     1995               16.474                         0.498     -0.242
#     1996               17.757                         0.566     -0.090
#     1997               16.754                         0.513      0.024
#
# [905 rows x 8 columns]

# %%
x_axis_residual = team_data_30seasons["Predicted Winning Percentage"]
y_axis_residual = team_data_30seasons["Residuals"]

plt.scatter(x_axis_residual, y_axis_residual, marker='.')
plt.xlabel("Predicted Winning Percentage", fontsize=12)
plt.ylabel("Residuals", fontsize=12)
plt.title("Predicted vs Residual", fontsize=16)
plt.hlines(0.0,x_axis_residual.min(), x_axis_residual.max(), colors='red', linestyles='solid')
#plt.xlim(0.6,0.88)
#plt.tight_layout()
plt.show()

# %%
season_data_2017 = four_factor.loc[(four_factor["Year"] > 2016.0)]
season_data_2017
# Out:
#        Year            Player   TM  eFG%  TOV%  ORB%    FT%  \
# 521    2017     Kent Bazemore  ATL  47.3  13.6   2.6  0.708
# 522    2017   DeAndre' Bembry  ATL  48.5  13.2   4.2  0.375
# 523    2017     Jose Calderon  ATL  47.4  19.9   3.2  0.875
# 524    2017   Malcolm Delaney  ATL  40.7  18.1   1.0  0.806
# 525    2017     Mike Dunleavy  ATL  56.5   9.0   3.1  0.846
# ...     ...               ...  ...   ...   ...   ...    ...
# 15062  2017       Otto Porter  WAS  60.8   4.8   5.1  0.832
# 15063  2017  Tomas Satoransky  WAS  44.9  19.1   3.9  0.697
# 15064  2017       Jason Smith  WAS  58.5  14.2   6.8  0.686
# 15065  2017   Marcus Thornton  WAS  46.7  10.1   4.3  0.852
# 15066  2017         John Wall  WAS  48.2  16.2   2.3  0.801
#
#        Winning Percentage  Four Factor Ratings
# 521                 0.575               16.146
# 522                 0.575               16.996
# 523                 0.575               14.756
# 524                 0.575               12.076
# 525                 0.575               21.097
# ...                   ...                  ...
# 15062               0.535               24.265
# 15063               0.535               14.070
# 15064               0.535               21.313
# 15065               0.535               17.143
# 15066               0.535               15.810
#
# [526 rows x 9 columns]

# %%
team_data_2017 = season_data_2017.groupby("TM").mean()
team_data_2017.head()
# Out:
#      Year       eFG%       TOV%      ORB%       FT%  Winning Percentage  \
# TM
# ATL  2017  47.430000  12.385000  3.915000  0.733100               0.575
# BOS  2017  53.966667  11.013333  5.513333  0.715533               0.625
# BRK  2017  49.576190  13.828571  4.428571  0.764571               0.214
# CHI  2017  45.683333  11.050000  4.400000  0.741706               0.477
# CHO  2017  46.957895  11.868421  5.342105  0.760833               0.512
#
#      Four Factor Ratings
# TM
# ATL            16.768650
# BOS            20.043467
# BRK            17.373762
# CHI            17.466176
# CHO            17.562222

# %%
team_data_2017["Predicted Winning Percentage"] = (slope_4ff * team_data_2017["Four Factor Ratings"]) + intercept_4ff

team_data_2017["Difference in Winning Percentages"] = (team_data_2017["Winning Percentage"] - 
                                                       team_data_2017["Predicted Winning Percentage"]) * 100

# %%
prediction_analysis_2017 = team_data_2017[["Four Factor Ratings", 
                                           "Predicted Winning Percentage", 
                                           "Winning Percentage", 
                                           "Difference in Winning Percentages"]]
prediction_analysis_2017
# Out:
#      Four Factor Ratings  Predicted Winning Percentage  Winning Percentage  \
# TM
# ATL            16.768650                      0.513997               0.575
# BOS            20.043467                      0.687835               0.625
# BRK            17.373762                      0.546118               0.214
# CHI            17.466176                      0.551024               0.477
# CHO            17.562222                      0.556123               0.512
# CLE            18.557650                      0.608963               0.714
# DAL            17.036217                      0.528200               0.341
# DEN            19.586389                      0.663572               0.419
# DET            16.930867                      0.522608               0.467
# GSW            18.639353                      0.613300               0.864
# HOU            18.589556                      0.610657               0.723
# IND            17.176000                      0.535621               0.512
# LAC            18.408714                      0.601057               0.644
# LAL            17.563722                      0.556202               0.333
# MEM            16.761529                      0.513619               0.565
# MIA            17.807733                      0.569155               0.318
# MIL            18.163375                      0.588034               0.465
# MIN            17.195600                      0.536661               0.364
# NOP            18.422609                      0.601795               0.386
# OKC            18.394389                      0.600297               0.568
# ORL            16.132400                      0.480223               0.391
# PHI            18.001850                      0.579459               0.357
# PHO            16.810667                      0.516227               0.341
# POR            18.068533                      0.582999               0.413
# SAC            18.356944                      0.598309               0.372
# SAS            18.482250                      0.604961               0.791
# TOR            18.702375                      0.616646               0.636
# UTA            18.724267                      0.617808               0.644
# WAS            16.371059                      0.492892               0.535
#
#      Difference in Winning Percentages
# TM
# ATL                           6.100291
# BOS                          -6.283519
# BRK                         -33.211843
# CHI                          -7.402410
# CHO                          -4.412253
# CLE                          10.503687
# DAL                         -18.720045
# DEN                         -24.457199
# DET                          -5.560809
# GSW                          25.069981
# HOU                          11.234322
# IND                          -2.362058
# LAC                           4.294287
# LAL                         -22.320215
# MEM                           5.138089
# MIA                         -25.115507
# MIL                         -12.303371
# MIN                         -17.266101
# NOP                         -21.579469
# OKC                          -3.229669
# ORL                          -8.922283
# PHI                         -22.245943
# PHO                         -17.522747
# POR                         -16.999920
# SAC                         -22.630901
# SAS                          18.603935
# TOR                           1.935439
# UTA                           2.619231
# WAS                           4.210837

# %%
print("Here are the teams for 2017:")
for i in range(len(prediction_analysis_2017.index)):
    print(prediction_analysis_2017.index[i])
# Out:
# Here are the teams for 2017:
# ATL
# BOS
# BRK
# CHI
# CHO
# CLE
# DAL
# DEN
# DET
# GSW
# HOU
# IND
# LAC
# LAL
# MEM
# MIA
# MIL
# MIN
# NOP
# OKC
# ORL
# PHI
# PHO
# POR
# SAC
# SAS
# TOR
# UTA
# WAS

# %%
user_team = input(f"For Prediction Analysis, please enter your team from Season 2017: ")
# Out:
# For Prediction Analysis, please enter your team from Season 2017: WAS

# %%
for tm,data in prediction_analysis_2017.iterrows():
    if tm == user_team:
        print(f"Actual Winning Percentage for {user_team} is: {data[2].round(decimals=3)}\n"
              f"Predicted Winning Percentage based on line equation formula for {user_team} is: {data[1].round(decimals=3)}\n"
              f"The difference in winning percentages is: {data[3].round(decimals=3)}%")
# Out:
# Actual Winning Percentage for WAS is: 0.535
# Predicted Winning Percentage based on line equation formula for WAS is: 0.493
# The difference in winning percentages is: 4.211%

# %% [markdown]
# #### Question 2 - Markdown

# %%
age_player_data =  complete_nba_data[["Year","Player","Age","G","MP","PER"]]
age_player_data
# Out:
#        Year            Player   Age     G      MP   PER
# 0      1986       John Battle  23.0  64.0   639.0  11.7
# 1      1986      Antoine Carr  24.0  17.0   258.0  14.4
# 2      1986   Lorenzo Charles  22.0  36.0   273.0  11.5
# 3      1986      Johnny Davis  30.0  27.0   402.0  13.9
# 4      1986    Scott Hastings  25.0  62.0   650.0   7.5
# ...     ...               ...   ...   ...     ...   ...
# 15257  1997    Rod Strickland  30.0  82.0  2997.0  19.7
# 15258  1997       Ben Wallace  22.0  34.0   197.0   6.0
# 15259  1997      Chris Webber  23.0  72.0  2806.0  21.8
# 15260  1997     Chris Whitney  25.0  82.0  1117.0  15.2
# 15261  1997  Lorenzo Williams  27.0  19.0   264.0   8.0
#
# [15262 rows x 6 columns]

# %%
mp_quartiles = age_player_data["MP"].quantile([.25,.5,.75])
lowerq_mp = mp_quartiles[.25]
median_mp = mp_quartiles[.5]
upperq_mp = mp_quartiles[.75]
iqr_mp = upperq_mp -lowerq_mp
lower_bound_mp = lowerq_mp - (1.5*iqr_mp)
upper_bound_mp = upperq_mp + (1.5*iqr_mp)


print(f"Lower Quartile: {lowerq_mp}\n"
      f"Median: {median_mp}\n"
      f"Upper Quartile: {upperq_mp}\n"
      f"IQR: {iqr_mp}\n"
      f"Upper Bound: {upper_bound_mp} & Lower Bound: {lower_bound_mp}\n")
# Out:
# Lower Quartile: 292.25
# Median: 972.0
# Upper Quartile: 1891.75
# IQR: 1599.5
# Upper Bound: 4291.0 & Lower Bound: -2107.0

# %%
game_quartiles = age_player_data["G"].quantile([.25,.5,.75])
lowerq_game = game_quartiles[.25]
median_game = game_quartiles[.5]
upperq_game = game_quartiles[.75]
iqr_game = upperq_game -lowerq_game
lower_bound_game = lowerq_game - (1.5*iqr_game)
upper_bound_game = upperq_game + (1.5*iqr_game)


print(f"Lower Quartile: {lowerq_game}\n"
      f"Median: {median_game}\n"
      f"Upper Quartile: {upperq_game}\n"
      f"IQR: {iqr_game}\n"
      f"Upper Bound: {upper_bound_game} & Lower Bound: {lower_bound_game}\n")
# Out:
# Lower Quartile: 24.0
# Median: 53.0
# Upper Quartile: 75.0
# IQR: 51.0
# Upper Bound: 151.5 & Lower Bound: -52.5

# %%
median_player = age_player_data.groupby("Player").median()
median_player
# Out:
#                       Year   Age     G      MP    PER
# Player
# A.C. Green          1994.0  30.0  82.0  2240.0  13.80
# A.J. Bramlett       2000.0  23.0   8.0    61.0  -0.40
# A.J. English        1991.5  23.5  75.5  1554.0  11.55
# A.J. Guyton         2002.0  23.0  33.0   607.0  10.30
# A.J. Hammons        2017.0  24.0  22.0   163.0   8.40
# ...                    ...   ...   ...     ...    ...
# Zeljko Rebraca      2004.0  31.0  29.5   450.0  14.00
# Zendon Hamilton     2004.0  28.0  11.0    46.0  13.50
# Zoran Dragic        2015.0  25.0   8.0    37.5   8.55
# Zoran Planinic      2005.0  22.0  49.0   515.0  10.00
# Zydrunas Ilgauskas  2005.0  29.0  73.0  2130.0  18.00
#
# [2501 rows x 5 columns]

# %%
top_players = median_player.loc[(median_player["G"]>=24.0) & (median_player["MP"]>=292.25)]
top_players
# Out:
#                       Year   Age     G      MP    PER
# Player
# A.C. Green          1994.0  30.0  82.0  2240.0  13.80
# A.J. English        1991.5  23.5  75.5  1554.0  11.55
# A.J. Guyton         2002.0  23.0  33.0   607.0  10.30
# A.J. Price          2013.5  26.5  36.0   380.5  11.10
# Aaron Brooks        2013.0  28.0  48.5   867.5  12.50
# ...                    ...   ...   ...     ...    ...
# Zarko Cabarkapa     2005.0  23.0  43.0   484.5  13.20
# Zaza Pachulia       2010.5  25.5  72.5  1361.0  14.05
# Zeljko Rebraca      2004.0  31.0  29.5   450.0  14.00
# Zoran Planinic      2005.0  22.0  49.0   515.0  10.00
# Zydrunas Ilgauskas  2005.0  29.0  73.0  2130.0  18.00
#
# [1523 rows x 5 columns]

# %%
x_axis = top_players["Age"]
y_axis = top_players["PER"]

# %%
(slope, intercept, r_value, p_value, std_err) = stats.linregress(x_axis,y_axis)

# %%
regress_value = slope*x_axis + intercept

# %%
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
plt.scatter(top_players["Age"],top_players["PER"])
plt.plot(x_axis,regress_value, "r-")
plt.annotate(line_eq,(33,25), fontsize=12, color="red")
plt.show()

# %% [markdown]
# #### Question 3 - Markdown

# %%
complete_nba_data.head()
# Out:
#    Index  Year           Player Pos   Age   Tm     G   GS     MP   PER  ...  \
# 0   7937  1986      John Battle  SG  23.0  ATL  64.0  0.0  639.0  11.7  ...
# 1   7963  1986     Antoine Carr  PF  24.0  ATL  17.0  0.0  258.0  14.4  ...
# 2   7973  1986  Lorenzo Charles  SF  22.0  ATL  36.0  0.0  273.0  11.5  ...
# 3   8000  1986     Johnny Davis  SG  30.0  ATL  27.0  7.0  402.0  13.9  ...
# 4   8050  1986   Scott Hastings  PF  25.0  ATL  62.0  0.0  650.0   7.5  ...
#
#      AST   STL   BLK   TOV     PF    PTS   Team  Record  Winning Percentage  \
# 0   74.0  23.0   3.0  47.0   80.0  277.0  Hawks   50-32                0.61
# 1   14.0   7.0  15.0  14.0   51.0  116.0  Hawks   50-32                0.61
# 2    8.0   2.0   6.0  18.0   37.0  122.0  Hawks   50-32                0.61
# 3  112.0  13.0   0.0  38.0   32.0  144.0  Hawks   50-32                0.61
# 4   26.0  14.0   8.0  40.0  118.0  193.0  Hawks   50-32                0.61
#
#     TM
# 0  ATL
# 1  ATL
# 2  ATL
# 3  ATL
# 4  ATL
#
# [5 rows x 57 columns]

# %%
player_points_data = complete_nba_data[["Year", "Player", "TM", "PTS", "Winning Percentage"]]
player_points_data["Player"] = player_points_data["Player"].str.replace("*","", regex=False)
player_points_data = player_points_data.sort_values(["Year"], ignore_index=True)
player_points_data
# Out:
# C:\Users\Jay D\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        Year             Player   TM     PTS  Winning Percentage
# 0      1986        John Battle  ATL   277.0               0.610
# 1      1986        John Paxson  CHI   395.0               0.366
# 2      1986         Mike Smrek  CHI   108.0               0.366
# 3      1986  Orlando Woolridge  CHI  1448.0               0.366
# 4      1986    Kiki Vandeweghe  POR  1962.0               0.488
# ...     ...                ...  ...     ...                 ...
# 15257  2017       Shelvin Mack  UTA   430.0               0.644
# 15258  2017          Raul Neto  UTA   100.0               0.644
# 15259  2017        Jeff Withey  UTA   146.0               0.644
# 15260  2017     Derrick Favors  UTA   476.0               0.644
# 15261  2017      James Michael  GSW   147.0               0.864
#
# [15262 rows x 5 columns]

# %%
sort_players_pts_data = player_points_data.sort_values(["PTS"], ascending = False, ignore_index=True)
sort_players_pts_data
# Out:
#        Year          Player   TM     PTS  Winning Percentage
# 0      1987  Michael Jordan  CHI  3041.0               0.488
# 1      1988  Michael Jordan  CHI  2868.0               0.610
# 2      2006     Kobe Bryant  LAL  2832.0               0.549
# 3      1990  Michael Jordan  CHI  2753.0               0.671
# 4      1989  Michael Jordan  CHI  2633.0               0.573
# ...     ...             ...  ...     ...                 ...
# 15257  1999      Brian Shaw  POR     0.0               0.700
# 15258  1995  Derrick Phelps  SAC     0.0               0.476
# 15259  2003      Guy Rucker  GSW     0.0               0.463
# 15260  1995       Greg Kite  NYK     0.0               0.671
# 15261  2000      Derek Hood  CHH     0.0               0.598
#
# [15262 rows x 5 columns]

# %%
top_10_players_pts = sort_players_pts_data.drop_duplicates(subset=["Player"], keep='first').head(10)
top_10_players_pts
# Out:
#     Year             Player   TM     PTS  Winning Percentage
# 0   1987     Michael Jordan  CHI  3041.0               0.488
# 2   2006        Kobe Bryant  LAL  2832.0               0.549
# 5   2014       Kevin Durant  OKC  2593.0               0.720
# 7   2017  Russell Westbrook  OKC  2558.0               0.568
# 9   1990        Karl Malone  UTA  2540.0               0.671
# 11  2006       LeBron James  CLE  2478.0               0.610
# 16  1986       Alex English  DEN  2414.0               0.573
# 17  2003      Tracy McGrady  ORL  2407.0               0.512
# 19  1988  Dominique Wilkins  ATL  2397.0               0.610
# 20  2009        Dwyane Wade  MIA  2386.0               0.524

# %%
# Write a loop to print top 10 players and give user input
top_10 = top_10_players_pts["Player"].tolist()
print(f"Top 10 NBA players based on points are: ")
for players in top_10:
    print(players)
# Out:
# Top 10 NBA players based on points are:
# Michael Jordan
# Kobe Bryant
# Kevin Durant
# Russell Westbrook
# Karl Malone
# LeBron James
# Alex English
# Tracy McGrady
# Dominique Wilkins
# Dwyane Wade

# %%
user_input = input('Enter your player name.')
user_input_data = player_points_data.loc[player_points_data["Player"] == user_input].reset_index()
user_input_data = user_input_data[["Year", "Player", "TM", "Winning Percentage"]]
user_input_data
# Out:
# Enter your player name.Alex English
#    Year        Player   TM  Winning Percentage
# 0  1986  Alex English  DEN               0.573
# 1  1987  Alex English  DEN               0.451
# 2  1988  Alex English  DEN               0.659
# 3  1989  Alex English  DEN               0.537
# 4  1990  Alex English  DEN               0.524
# 5  1991  Alex English  DAL               0.341

# %%
new_team = []
year = []
winning_percentage = []
pvs_team_winning_percent_list = []
difference_percent = []
change = 0

old_team = user_input_data.iloc[0,2]

for row,values in user_input_data.iterrows():
    if values[2] != old_team:
        newTm = values[2]
        newYr = values[0] - 1
        pv_team_Data = combined_team_data.loc[(combined_team_data['TM'] == newTm) & (combined_team_data['Year'] == newYr)]
        if (pv_team_Data.empty == False):
            pvs_team_winning_percent = pv_team_Data.values[0][3]
            pvs_team_winning_percent_list.append(pvs_team_winning_percent)
            win_Perc =  values[3] - pvs_team_winning_percent
            difference_percent.append(win_Perc)
            new_team.append(values[2])
            year.append(values[0])
            winning_percentage.append(values[3])
            old_team = values[2]
            change =+ 1

summary = pd.DataFrame({
        'Year' : year , 
        'Team': new_team,
        'Old Winning Percent': pvs_team_winning_percent_list,
        'New Wining Percent': winning_percentage,
        'Difference' : difference_percent
})

if change == 0:
    print(f"Player did not change his team")
else:
    print(summary)
# Out:
#    Year Team  Old Winning Percent  New Wining Percent  Difference
# 0  1991  DAL                0.573               0.341      -0.232

# %%
# user_input = input('Enter your player name.')
while True:
    try:
        user_input = str(input('Enter your player name.'))
        if top_10.count(user_input) > 0 :
            except ValueError:
                print("Sorry, I didn't understand that.")
                continue
    else:
        break
user_input_data = player_points_data.loc[player_points_data["Player"] == user_input].reset_index()
user_input_data = user_input_data[["Year", "Player", "TM", "Winning Percentage"]]
user_input_data
# Out:
#   File "<ipython-input-67-3761485728cd>", line 6
#     except ValueError:
#          ^
# SyntaxError: invalid syntax

# %%
sams_data = complete_nba_data[['Player', 'PER', 'TS%', 'ORB%', 'DRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'WS', '3P%', '2P%', 'FT%', 'PTS', 'MP']]
sams_data.head()

Q1=sams_data.quantile(0.25)
Q3=sams_data.quantile(0.75)
IQR=Q3-Q1

sams_no_outlier = sams_data[~((sams_data<(Q1-1.5*IQR)))]
